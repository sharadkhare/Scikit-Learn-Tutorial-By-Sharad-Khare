# %%
# Business Problem Statement:
'''Imagine you are working for an e-commerce company, and the marketing
team wants to better understand the purchasing behavior of customers.
They want to identify distinct groups of customers based on their 
buying patterns so that they can tailor marketing strategies for each
group. However, the dataset they have is high-dimensional, making it 
challenging to visualize and analyze.'''
# T-SNE (t-distributed Stochastic Neighbor Embedding)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
data,labels = make_blobs(n_samples=300, centers=3,random_state=42)

# %%
data_standardized = StandardScaler().fit_transform(data)

# %%
tsne = TSNE(n_components=2,random_state=42)
data_tsne = tsne.fit_transform(data_standardized)

# %%
# visualize
plt.scatter(data_tsne[:,0],data[:,1], c=labels,cmap='viridis')
plt.title("T-sne visualization of custmer segment")
plt.xlabel("t-sne component 1")
plt.ylabel("t-sne component 2")
plt.show()
